# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
import requests

def download(url, filename):
    r = requests.get(url)
    if r.status_code == 200:
        with open(filename, "wb") as f:
            f.write(r.content)
        print("File downloaded successfully.")
    else:
        print("File not downloaded. Status Code:", r.status_code)

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv"

filename = "module_5_auto.csv"

download(url, filename)
# Out:
# File downloaded successfully.

# %%
df = pd.read_csv('module_5_auto.csv',header=0)

# %%
df.head(20)
# Out:
#     Unnamed: 0.1  Unnamed: 0  symboling  normalized-losses         make  \
# 0              0           0          3                122  alfa-romero
# 1              1           1          3                122  alfa-romero
# 2              2           2          1                122  alfa-romero
# 3              3           3          2                164         audi
# 4              4           4          2                164         audi
# 5              5           5          2                122         audi
# 6              6           6          1                158         audi
# 7              7           7          1                122         audi
# 8              8           8          1                158         audi
# 9              9           9          2                192          bmw
# 10            10          10          0                192          bmw
# 11            11          11          0                188          bmw
# ...

# %%
df = df._get_numeric_data()
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  symboling  normalized-losses  wheel-base  \
# 0               0           0          3                122        88.6
# 1               1           1          3                122        88.6
# 2               2           2          1                122        94.5
# 3               3           3          2                164        99.8
# 4               4           4          2                164        99.4
# ..            ...         ...        ...                ...         ...
# 196           196         196         -1                 95       109.1
# 197           197         197         -1                 95       109.1
# 198           198         198         -1                 95       109.1
# 199           199         199         -1                 95       109.1
# 200           200         200         -1                 95       109.1
#
#        length     width  height  curb-weight  engine-size  ...  stroke  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  symboling  normalized-losses  wheel-base  \
# 0             0           0          3                122        88.6
# 1             1           1          3                122        88.6
# 2             2           2          1                122        94.5
# 3             3           3          2                164        99.8
# 4             4           4          2                164        99.4
#
#      length     width  height  curb-weight  engine-size  ...  stroke  \
# 0  0.811148  0.890278    48.8         2548          130  ...    2.68
# 1  0.811148  0.890278    48.8         2548          130  ...    2.68
# 2  0.822681  0.909722    52.4         2823          152  ...    3.47
# 3  0.848630  0.919444    54.3         2337          109  ...    3.40
# 4  0.848630  0.922222    54.3         2824          136  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# ...

# %%
#lets remove column Unnamed: 0.1	Unnamed: 0
df.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace = True)
df.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width  height  \
# 0          3                122        88.6  0.811148  0.890278    48.8
# 1          3                122        88.6  0.811148  0.890278    48.8
# 2          1                122        94.5  0.822681  0.909722    52.4
# 3          2                164        99.8  0.848630  0.919444    54.3
# 4          2                164        99.4  0.848630  0.922222    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price  city-L/100km  diesel  gas
# ...

# %% [markdown]
# **function for plotting**

# %%
def DistributionPlot(RedFunction,BlueFunction,RedName,BlueName,Title):
    plt.Figure(figsize=(12,4))
    ax1 = sns.kdeplot(RedFunction,color = 'r',label = 'RedName')
    ax2 = sns.kdeplot(BlueFunction,color = 'b',label = 'BlueName')

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')
    plt.show()

# %%
def pollyplot(xtrain,xtest,y_train,y_test,lr,poly_transform):

    plt.Figure(figsize=(12,5))

    xmax = max([xtrain.values.max(),xtest.values.max()])
    xmin = max([xtrain.values.min(),xtest.values.min()])
    x = np.arrange(xmax,xmin,0.1)

    plt.plot(xtrain,y_train,'ro',label = 'Training_data')
    plt.plot(xtest,y_test,'go',label = 'Test_data')
    plt.plot(x,lr.predict(poly_transform.fit_transform(x.reshape(-1,1))),label = 'Predicted_function')
    plt.ylim([-10000,60000])
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %% [markdown]
# **Part 1: Training and Testing**

# %%
y_data = df['price']

# %%
x_data = df.drop('price',axis = 1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x_data,y_data,test_size=0.10,random_state = 1)

print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 21
# number of training samples: 180

# %%
from sklearn.model_selection import train_test_split

x_train1,x_test1,y_train1,y_test1 = train_test_split(x_data,y_data,test_size=0.4,random_state=0)

print("number of test samples :", x_test1.shape[0])
print("number of training samples:",x_train1.shape[0])
# Out:
# number of test samples : 81
# number of training samples: 120

# %% [markdown]
# **Let's import LinearRegression from the module linear_model.**

# %%
from sklearn.linear_model import LinearRegression

lrm = LinearRegression()
#We fit the model using the feature "horsepower":
lrm.fit(x_train[['horsepower']],y_train)
#Let's calculate the R^2 on the test data:
lrm.score(x_test[['horsepower']],y_test)
# Out:
# 0.3635875575078824

# %%
lrm.score(x_train[['horsepower']],y_train)
# Out:
# 0.6619724197515103

# %% [markdown]
# **Find the R^2 on the test data using 40% of the dataset for testing.**

# %%
x_train1,x_test1,y_train1,y_test1 = train_test_split(x_data,y_data,test_size=0.4,random_state=0)
lrm.fit(x_test1[['horsepower']],y_test1)
# Out:
# LinearRegression()

# %%
lrm.score(x_train1[['horsepower']],y_train1)
# Out:
# 0.4850746538215115

# %% [markdown]
# **Cross-Validation Score**

# %%
from sklearn.model_selection import cross_val_score
#We input the object, the feature ("horsepower"), and the target data (y_data). The parameter 'cv' determines the number of folds. In this case, it is 4.
Rcross = cross_val_score(lrm,x_data[['horsepower']],y_data,cv= 4)
Rcross
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %%
print("mean of the folds are:",Rcross.mean(),"Standard deviation of folds are:",Rcross.std())
# Out:
# mean of the folds are: 0.5220099150421194 Standard deviation of folds are: 0.2911839444756025

# %%
# We can use negative squared error as a score by setting the parameter 'scoring' metric to 'neg_mean_squared_error'.
-1 * cross_val_score(lrm,x_data[['horsepower']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([20254142.84026704, 43745493.26505169, 12539630.34014931,
#        17561927.72247589])

# %%
from sklearn.model_selection import cross_val_predict

yhat = cross_val_predict(lrm,x_data[['horsepower']],y_data,cv = 4)
yhat
# Out:
# array([14141.63807508, 14141.63807508, 20814.29423473, 12745.03562306,
#        14762.35027598, 13986.46002486, 13986.46002486, 13986.46002486,
#        18641.80153159, 12589.85757284, 12589.85757284, 15693.41857732,
#        15693.41857732, 15693.41857732, 25159.27964101, 25159.27964101,
#        25159.27964101,  4365.42091095,  7779.33801589,  7779.33801589,
#         7468.98191544,  7468.98191544, 12745.03562306,  7468.98191544,
#         7468.98191544,  7468.98191544, 12745.03562306, 10572.54291992,
#        19417.69178271,  5917.2014132 ,  8710.40631723,  6227.55751364,
#         8710.40631723,  8710.40631723,  8710.40631723,  8710.40631723,
#        10262.18681948, 10262.18681948, 10262.18681948, 10262.18681948,
#        12589.85757284, 12434.67952262,  9020.76241768, 10882.89902037,
#        24228.21133966, 24228.21133966, 37573.52365895,  7468.98191544,
#         7468.98191544,  7468.98191544,  7468.98191544,  7191.77534249,
# ...

# %% [markdown]
# *******Part 2: Overfitting, Underfitting and Model Selection*******

# %%
#overfitting
from sklearn.preprocessing import PolynomialFeatures

x_train2,x_test2,y_train2,y_test2 = train_test_split(x_data,y_data,test_size=0.45,random_state=1)

pr = PolynomialFeatures(degree=5)
x_train_pr = pr.fit_transform(x_train[['horsepower']])
x_test_pr = pr.fit_transform(x_test[['horsepower']])
pr
# Out:
# PolynomialFeatures(degree=5)
